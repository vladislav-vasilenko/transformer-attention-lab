# %% [markdown]
# # Этап 1: Продвинутый анализ потенциала сжатия
#
# Мы уже знаем размер модели. Теперь давайте выясним, насколько она «хрупкая» и где прячутся главные враги квантования.

# %%
# Настройка путей: если мы в подпапке, переходим в корень проекта
import torch
import matplotlib.pyplot as plt
import numpy as np
from src.model import GPTLanguageModel, device

# Загружаем модель (желательно уже обученную)
model = GPTLanguageModel().to(device)
try:
    model.load_state_dict(torch.load('nanoGPT-lab/model_ckpt.pt', map_location=device))
    print("✅ Загружены обученные веса из model_ckpt.pt")
except:
    print("⚠️ Чекпоинт не найден, используем случайные веса (результаты будут менее точными)")

model.eval()
# Out:
# Using device: mps
# Using device: mps
# ✅ Загружены обученные веса из model_ckpt.pt
# GPTLanguageModel(
#   (token_embedding_table): Embedding(65, 384)
#   (position_embedding_table): Embedding(256, 384)
#   (blocks): Sequential(
#     (0): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-5): 6 x Head(
#             (key): Linear(in_features=384, out_features=64, bias=False)
#             (query): Linear(in_features=384, out_features=64, bias=False)
#             (value): Linear(in_features=384, out_features=64, bias=False)
#             (dropout): Dropout(p=0.2, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#       )
#       (ffwd): FeedFoward(
#         (net): Sequential(
#           (0): Linear(in_features=384, out_features=1536, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=1536, out_features=384, bias=True)
#           (3): Dropout(p=0.2, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-5): 6 x Head(
#             (key): Linear(in_features=384, out_features=64, bias=False)
#             (query): Linear(in_features=384, out_features=64, bias=False)
#             (value): Linear(in_features=384, out_features=64, bias=False)
#             (dropout): Dropout(p=0.2, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#       )
#       (ffwd): FeedFoward(
#         (net): Sequential(
#           (0): Linear(in_features=384, out_features=1536, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=1536, out_features=384, bias=True)
#           (3): Dropout(p=0.2, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     )
#     (2): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-5): 6 x Head(
#             (key): Linear(in_features=384, out_features=64, bias=False)
#             (query): Linear(in_features=384, out_features=64, bias=False)
#             (value): Linear(in_features=384, out_features=64, bias=False)
#             (dropout): Dropout(p=0.2, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#       )
#       (ffwd): FeedFoward(
#         (net): Sequential(
#           (0): Linear(in_features=384, out_features=1536, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=1536, out_features=384, bias=True)
#           (3): Dropout(p=0.2, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     )
#     (3): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-5): 6 x Head(
#             (key): Linear(in_features=384, out_features=64, bias=False)
#             (query): Linear(in_features=384, out_features=64, bias=False)
#             (value): Linear(in_features=384, out_features=64, bias=False)
#             (dropout): Dropout(p=0.2, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#       )
#       (ffwd): FeedFoward(
#         (net): Sequential(
#           (0): Linear(in_features=384, out_features=1536, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=1536, out_features=384, bias=True)
#           (3): Dropout(p=0.2, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     )
#     (4): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-5): 6 x Head(
#             (key): Linear(in_features=384, out_features=64, bias=False)
#             (query): Linear(in_features=384, out_features=64, bias=False)
#             (value): Linear(in_features=384, out_features=64, bias=False)
#             (dropout): Dropout(p=0.2, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#       )
#       (ffwd): FeedFoward(
#         (net): Sequential(
#           (0): Linear(in_features=384, out_features=1536, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=1536, out_features=384, bias=True)
#           (3): Dropout(p=0.2, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     )
#     (5): Block(
#       (sa): MultiHeadAttention(
#         (heads): ModuleList(
#           (0-5): 6 x Head(
#             (key): Linear(in_features=384, out_features=64, bias=False)
#             (query): Linear(in_features=384, out_features=64, bias=False)
#             (value): Linear(in_features=384, out_features=64, bias=False)
#             (dropout): Dropout(p=0.2, inplace=False)
#           )
#         )
#         (proj): Linear(in_features=384, out_features=384, bias=True)
#         (dropout): Dropout(p=0.2, inplace=False)
#       )
#       (ffwd): FeedFoward(
#         (net): Sequential(
#           (0): Linear(in_features=384, out_features=1536, bias=True)
#           (1): ReLU()
#           (2): Linear(in_features=1536, out_features=384, bias=True)
#           (3): Dropout(p=0.2, inplace=False)
#         )
#       )
#       (ln1): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#       (ln2): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#     )
#   )
#   (ln_f): LayerNorm((384,), eps=1e-05, elementwise_affine=True)
#   (lm_head): Linear(in_features=384, out_features=65, bias=True)
# )

# %% [markdown]
# ### 1. Анализ Выбросов (Outliers Analysis)
# Выбросы — это значения весов, которые сильно выбиваются из общего распределения. Они заставляют квантователь выбирать слишком широкий диапазон, из-за чего 99% обычных весов теряют точность.

# %%
def analyze_outliers(mdl, threshold_sigma=3.0):
    print(f"{'Layer Name':<40} | {'Max Val':<10} | {'Outliers %':<10}")
    print("-" * 70)
    
    for name, param in mdl.named_parameters():
        if 'weight' in name and param.dim() > 1:
            data = param.data.cpu().numpy().flatten()
            mean = np.mean(data)
            std = np.std(data)
            
            # Считаем сколько весов выходят за пределы N сигм
            outliers = np.sum(np.abs(data - mean) > threshold_sigma * std)
            outlier_pct = (outliers / len(data)) * 100
            
            print(f"{name[:40]:<40} | {np.max(np.abs(data)):<10.4f} | {outlier_pct:<10.2f}%")

analyze_outliers(model)
# Out:
# Layer Name                               | Max Val    | Outliers %
# ----------------------------------------------------------------------
# token_embedding_table.weight             | 0.1615     | 0.40      %
# position_embedding_table.weight          | 0.1935     | 0.39      %
# blocks.0.sa.heads.0.key.weight           | 0.1486     | 0.46      %
# blocks.0.sa.heads.0.query.weight         | 0.1215     | 0.33      %
# blocks.0.sa.heads.0.value.weight         | 0.0781     | 0.28      %
# blocks.0.sa.heads.1.key.weight           | 0.1687     | 0.45      %
# blocks.0.sa.heads.1.query.weight         | 0.1512     | 0.32      %
# blocks.0.sa.heads.1.value.weight         | 0.0827     | 0.30      %
# blocks.0.sa.heads.2.key.weight           | 0.1428     | 0.41      %
# blocks.0.sa.heads.2.query.weight         | 0.1360     | 0.30      %
# blocks.0.sa.heads.2.value.weight         | 0.0716     | 0.26      %
# blocks.0.sa.heads.3.key.weight           | 0.1478     | 0.53      %
# blocks.0.sa.heads.3.query.weight         | 0.1239     | 0.35      %
# blocks.0.sa.heads.3.value.weight         | 0.0784     | 0.24      %
# blocks.0.sa.heads.4.key.weight           | 0.1514     | 0.56      %
# blocks.0.sa.heads.4.query.weight         | 0.1517     | 0.30      %
# blocks.0.sa.heads.4.value.weight         | 0.0740     | 0.29      %
# blocks.0.sa.heads.5.key.weight           | 0.1567     | 0.42      %
# blocks.0.sa.heads.5.query.weight         | 0.1590     | 0.34      %
# blocks.0.sa.heads.5.value.weight         | 0.0735     | 0.33      %
# blocks.0.sa.proj.weight                  | 0.0724     | 0.32      %
# blocks.0.ffwd.net.0.weight               | 0.1547     | 0.34      %
# blocks.0.ffwd.net.2.weight               | 0.1078     | 0.28      %
# blocks.1.sa.heads.0.key.weight           | 0.0910     | 0.31      %
# blocks.1.sa.heads.0.query.weight         | 0.0988     | 0.29      %
# blocks.1.sa.heads.0.value.weight         | 0.0884     | 0.34      %
# blocks.1.sa.heads.1.key.weight           | 0.0932     | 0.26      %
# blocks.1.sa.heads.1.query.weight         | 0.0935     | 0.34      %
# blocks.1.sa.heads.1.value.weight         | 0.0731     | 0.26      %
# blocks.1.sa.heads.2.key.weight           | 0.0863     | 0.32      %
# blocks.1.sa.heads.2.query.weight         | 0.0941     | 0.27      %
# blocks.1.sa.heads.2.value.weight         | 0.0850     | 0.28      %
# blocks.1.sa.heads.3.key.weight           | 0.0967     | 0.24      %
# blocks.1.sa.heads.3.query.weight         | 0.1040     | 0.27      %
# blocks.1.sa.heads.3.value.weight         | 0.0773     | 0.28      %
# blocks.1.sa.heads.4.key.weight           | 0.0984     | 0.25      %
# blocks.1.sa.heads.4.query.weight         | 0.0915     | 0.23      %
# blocks.1.sa.heads.4.value.weight         | 0.0751     | 0.27      %
# blocks.1.sa.heads.5.key.weight           | 0.1062     | 0.29      %
# blocks.1.sa.heads.5.query.weight         | 0.0938     | 0.25      %
# blocks.1.sa.heads.5.value.weight         | 0.0797     | 0.29      %
# blocks.1.sa.proj.weight                  | 0.0877     | 0.27      %
# blocks.1.ffwd.net.0.weight               | 0.1341     | 0.32      %
# blocks.1.ffwd.net.2.weight               | 0.1059     | 0.31      %
# blocks.2.sa.heads.0.key.weight           | 0.1393     | 0.35      %
# blocks.2.sa.heads.0.query.weight         | 0.1326     | 0.25      %
# blocks.2.sa.heads.0.value.weight         | 0.0863     | 0.25      %
# blocks.2.sa.heads.1.key.weight           | 0.1120     | 0.35      %
# blocks.2.sa.heads.1.query.weight         | 0.1222     | 0.30      %
# blocks.2.sa.heads.1.value.weight         | 0.1163     | 0.27      %
# blocks.2.sa.heads.2.key.weight           | 0.1058     | 0.33      %
# blocks.2.sa.heads.2.query.weight         | 0.1001     | 0.27      %
# blocks.2.sa.heads.2.value.weight         | 0.0824     | 0.28      %
# blocks.2.sa.heads.3.key.weight           | 0.1234     | 0.37      %
# blocks.2.sa.heads.3.query.weight         | 0.1411     | 0.28      %
# blocks.2.sa.heads.3.value.weight         | 0.0918     | 0.28      %
# blocks.2.sa.heads.4.key.weight           | 0.1284     | 0.36      %
# blocks.2.sa.heads.4.query.weight         | 0.1459     | 0.29      %
# blocks.2.sa.heads.4.value.weight         | 0.0851     | 0.26      %
# blocks.2.sa.heads.5.key.weight           | 0.1307     | 0.40      %
# blocks.2.sa.heads.5.query.weight         | 0.1303     | 0.29      %
# blocks.2.sa.heads.5.value.weight         | 0.0871     | 0.28      %
# blocks.2.sa.proj.weight                  | 0.0908     | 0.32      %
# blocks.2.ffwd.net.0.weight               | 0.1267     | 0.33      %
# blocks.2.ffwd.net.2.weight               | 0.1170     | 0.32      %
# blocks.3.sa.heads.0.key.weight           | 0.1328     | 0.29      %
# blocks.3.sa.heads.0.query.weight         | 0.1234     | 0.29      %
# blocks.3.sa.heads.0.value.weight         | 0.0975     | 0.28      %
# blocks.3.sa.heads.1.key.weight           | 0.1520     | 0.41      %
# blocks.3.sa.heads.1.query.weight         | 0.1283     | 0.34      %
# blocks.3.sa.heads.1.value.weight         | 0.0869     | 0.25      %
# blocks.3.sa.heads.2.key.weight           | 0.1200     | 0.35      %
# blocks.3.sa.heads.2.query.weight         | 0.1326     | 0.30      %
# blocks.3.sa.heads.2.value.weight         | 0.0956     | 0.28      %
# blocks.3.sa.heads.3.key.weight           | 0.1329     | 0.46      %
# blocks.3.sa.heads.3.query.weight         | 0.1327     | 0.33      %
# blocks.3.sa.heads.3.value.weight         | 0.0906     | 0.26      %
# blocks.3.sa.heads.4.key.weight           | 0.1242     | 0.33      %
# blocks.3.sa.heads.4.query.weight         | 0.1401     | 0.33      %
# blocks.3.sa.heads.4.value.weight         | 0.0954     | 0.30      %
# blocks.3.sa.heads.5.key.weight           | 0.1384     | 0.33      %
# blocks.3.sa.heads.5.query.weight         | 0.1241     | 0.27      %
# blocks.3.sa.heads.5.value.weight         | 0.0962     | 0.29      %
# blocks.3.sa.proj.weight                  | 0.1123     | 0.29      %
# blocks.3.ffwd.net.0.weight               | 0.1440     | 0.35      %
# blocks.3.ffwd.net.2.weight               | 0.1286     | 0.32      %
# blocks.4.sa.heads.0.key.weight           | 0.1337     | 0.40      %
# blocks.4.sa.heads.0.query.weight         | 0.1106     | 0.24      %
# blocks.4.sa.heads.0.value.weight         | 0.0796     | 0.25      %
# blocks.4.sa.heads.1.key.weight           | 0.1143     | 0.42      %
# blocks.4.sa.heads.1.query.weight         | 0.1251     | 0.35      %
# blocks.4.sa.heads.1.value.weight         | 0.0886     | 0.33      %
# blocks.4.sa.heads.2.key.weight           | 0.1104     | 0.45      %
# blocks.4.sa.heads.2.query.weight         | 0.1215     | 0.32      %
# blocks.4.sa.heads.2.value.weight         | 0.0872     | 0.33      %
# blocks.4.sa.heads.3.key.weight           | 0.1296     | 0.40      %
# blocks.4.sa.heads.3.query.weight         | 0.1256     | 0.37      %
# blocks.4.sa.heads.3.value.weight         | 0.0900     | 0.29      %
# blocks.4.sa.heads.4.key.weight           | 0.1365     | 0.35      %
# blocks.4.sa.heads.4.query.weight         | 0.1263     | 0.37      %
# blocks.4.sa.heads.4.value.weight         | 0.0942     | 0.33      %
# blocks.4.sa.heads.5.key.weight           | 0.1391     | 0.41      %
# blocks.4.sa.heads.5.query.weight         | 0.1265     | 0.31      %
# blocks.4.sa.heads.5.value.weight         | 0.0945     | 0.26      %
# blocks.4.sa.proj.weight                  | 0.1022     | 0.29      %
# blocks.4.ffwd.net.0.weight               | 0.1311     | 0.36      %
# blocks.4.ffwd.net.2.weight               | 0.1313     | 0.37      %
# blocks.5.sa.heads.0.key.weight           | 0.1196     | 0.39      %
# blocks.5.sa.heads.0.query.weight         | 0.1397     | 0.31      %
# blocks.5.sa.heads.0.value.weight         | 0.0967     | 0.37      %
# blocks.5.sa.heads.1.key.weight           | 0.1165     | 0.46      %
# blocks.5.sa.heads.1.query.weight         | 0.1183     | 0.30      %
# blocks.5.sa.heads.1.value.weight         | 0.0949     | 0.26      %
# blocks.5.sa.heads.2.key.weight           | 0.1268     | 0.40      %
# blocks.5.sa.heads.2.query.weight         | 0.1163     | 0.31      %
# blocks.5.sa.heads.2.value.weight         | 0.0917     | 0.33      %
# blocks.5.sa.heads.3.key.weight           | 0.1229     | 0.33      %
# blocks.5.sa.heads.3.query.weight         | 0.1207     | 0.30      %
# blocks.5.sa.heads.3.value.weight         | 0.0896     | 0.33      %
# blocks.5.sa.heads.4.key.weight           | 0.1125     | 0.35      %
# blocks.5.sa.heads.4.query.weight         | 0.1145     | 0.34      %
# blocks.5.sa.heads.4.value.weight         | 0.0923     | 0.25      %
# blocks.5.sa.heads.5.key.weight           | 0.1286     | 0.35      %
# blocks.5.sa.heads.5.query.weight         | 0.1132     | 0.30      %
# blocks.5.sa.heads.5.value.weight         | 0.0874     | 0.31      %
# blocks.5.sa.proj.weight                  | 0.1103     | 0.30      %
# blocks.5.ffwd.net.0.weight               | 0.1593     | 0.39      %
# blocks.5.ffwd.net.2.weight               | 0.1565     | 0.42      %
# lm_head.weight                           | 0.1752     | 0.25      %

# %% [markdown]
# ### 2. Saliency: Какие слои важнее?
# Мы добавим к весам шум разной амплитуды и посмотрим, как это влияет на Loss. Это покажет нам «чувствительность» модели к порче данных.

# %%
from src.utils import get_batch

def measure_sensitivity(mdl, noise_level=0.01):
    xb, yb = get_batch('val')
    
    # Базовый лосс
    with torch.no_grad():
        _, base_loss = mdl(xb, yb)
    
    print(f"Базовый Loss на валидации: {base_loss.item():.4f}\n")
    print(f"{'Layer to noise':<40} | {'Delta Loss':<10} | {'Sensitivity'}")
    print("-" * 75)

    for name, param in mdl.named_parameters():
        if 'weight' in name and param.dim() > 1:
            orig_data = param.data.clone()
            
            # Добавляем шум
            noise = torch.randn_like(param.data) * noise_level
            param.data.add_(noise)
            
            with torch.no_grad():
                _, new_loss = mdl(xb, yb)
            
            delta = new_loss.item() - base_loss.item()
            
            # Оценка: чем выше Sensitivity, тем опаснее сжимать этот слой
            sensitivity = "🔴 HIGH" if delta > 0.05 else ("🟡 MED" if delta > 0.01 else "🟢 LOW")
            
            print(f"{name[:40]:<40} | {delta:<10.4f} | {sensitivity}")
            
            # Возвращаем веса назад!
            param.data.copy_(orig_data)

measure_sensitivity(model)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from src.model import get_batch
#       3 def measure_sensitivity(mdl, noise_level=0.01):
#       4     xb, yb = get_batch('val')
#
# ImportError: cannot import name 'get_batch' from 'src.model' (/Users/vladmac/Code/ML-Colab/Andrey Karpathy Lessons/nanoGPT-lab/src/model.py)

# %% [markdown]
# ### Выводы Этапа 1:
# 1. **Outliers**: Если процент выбросов высок, обычное квантование (Min-Max) сильно уронит точность. Нам понадобятся методы вроде **Clamping** или **SmoothQuant**.
# 2. **Sensitivity**: Слои с пометкой 🔴 HIGH нужно сохранять в максимальной точности (например, оставить в FP16) или использовать для них большее количество бит.
